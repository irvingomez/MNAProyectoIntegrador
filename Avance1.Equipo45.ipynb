# %% [markdown]
# ## Maestría en Inteligencia Artificial Aplicada
#
# ### PROYECTO INTEGRADOR
#
# MODELO ML PREDICCION DE ABANDONO DE TARJETA DE CREDITO
#
# ANALISIS EXPLORATORIO DE LOS DATOS
#
# Equipo 45
#
# Felipe de Jesús Gastélum Lizárraga - A01114918
#
# Jonathan Montaña Vásquez - A01793920
#
# Irvin Gómez Esquivel - A00361034
#
# 5/5/2024

# %% [markdown]
# ### Introducción
#
# El presente notebook contiene el análisis exploratorio de los datos para el proyecto de Modelo de Machine Learning para la Predicción de Abandono de Tarjeta de Crédito.
#
# Durante este notebook analizaremos los datos, identificaremos nulos o faltantes, identificaremos datos categóricos y definiremos la mejor forma de transformarlos a numéricos, haremos análisis univariante a manera de histogramas y boxplots.
#
# También veremos la matriz de correlación y haremos un análisis de componentes (PCA).
#
# Por último haremos un análisis de la variable de salida.

# %% [markdown]
# ### Preparación

# %%
# librerías y paquetes que requieras.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

from sklearn.model_selection import train_test_split #Para hacer las particiones
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, make_scorer
from imblearn.metrics import geometric_mean_score, classification_report_imbalanced
from sklearn.model_selection import  cross_validate,  RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from io import BytesIO

#Librerias de modelos
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ### Carga del dataset

# %%
#Establecer coneccion con drive para poder cargar el arhivo de la base de datos
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importar base de datos

import requests, zipfile
from io import *

url='https://drive.google.com/file/d/1g7GJ6JYnPkTc4G7WGrT3ZvMAl9nPsw_J/view?usp=drive_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

req = requests.get(url)
print('Downloading Completed')





# extracting the zip file contents
zipfile= zipfile.ZipFile(BytesIO(req.content))
zipfile.extractall('/content/sample_data/AbandonoTarjeta')
df = pd.read_csv("/content/sample_data/AbandonoTarjeta/BankChurners.csv",sep=',')
# Out:
# Downloading Completed

# %% [markdown]
# ### Estructura de los datos

# %%
#Vista General de Columnas y Primeros datos
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
#Información Estadistica General
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990

# %%
#Verificar si hay columnas con valores nulos
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# Income_Category                                                                                                                       0
# Card_Category                                                                                                                         0
# Months_on_book                                                                                                                        0
# Total_Relationship_Count                                                                                                              0
# Months_Inactive_12_mon                                                                                                                0
# Contacts_Count_12_mon                                                                                                                 0
# Credit_Limit                                                                                                                          0
# Total_Revolving_Bal                                                                                                                   0
# Avg_Open_To_Buy                                                                                                                       0
# Total_Amt_Chng_Q4_Q1                                                                                                                  0
# Total_Trans_Amt                                                                                                                       0
# Total_Trans_Ct                                                                                                                        0
# Total_Ct_Chng_Q4_Q1                                                                                                                   0
# Avg_Utilization_Ratio                                                                                                                 0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1    0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2    0
# dtype: int64

# %% [markdown]
# Con lo anterior, podemos observar que el dataset no tiene valores nulos

# %% [markdown]
# ### Análisis de datos categóricos

# %% [markdown]
# #### Identificación de valores categóricos

# %% [markdown]
# Ahora buscamos los valores categóricos que luego convertiremos a valores numéricos

# %%
print("Gender")
print(df["Gender"].unique())
print("Education Level")
print(df["Education_Level"].unique())
print("Income Category")
print(df["Income_Category"].unique())
print("Marital Status")
print(df["Marital_Status"].unique())
print("Card Category")
print(df["Card_Category"].unique())
# Out:
# Gender
# ['M' 'F']
# Education Level
# ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
# Income Category
# ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# Marital Status
# ['Married' 'Single' 'Unknown' 'Divorced']
# Card Category
# ['Blue' 'Gold' 'Silver' 'Platinum']

# %% [markdown]
# Observamos que tanto en Education Level, Income Category y Martial Status tenemos rows de Unknown, vamos a revisar cuantos registros tenemos de cada uno para saber si los incluimos en la transformación o si mejor los eliminamos

# %% [markdown]
# ### Preprocesamiento

# %% [markdown]
# #### Conteo de valores desconocidos

# %%
df[df.Education_Level=="Unknown"]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 6      810347208  Existing Customer            51      M                4
# 11     710821833  Existing Customer            65      M                1
# 15     714885258  Existing Customer            44      M                4
# 17     753327333  Existing Customer            41      M                3
# 23     811604133  Existing Customer            47      F                4
# ...          ...                ...           ...    ...              ...
# 10090  712296408  Existing Customer            36      F                3
# 10094  716123283  Existing Customer            59      M                1
# 10095  789023508  Existing Customer            46      M                3
# 10118  713755458  Attrited Customer            50      M                1
# 10123  710638233  Attrited Customer            41      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 6             Unknown        Married         $120K +          Gold
# 11            Unknown        Married     $40K - $60K          Blue
# 15            Unknown        Unknown    $80K - $120K          Blue
# 17            Unknown        Married    $80K - $120K          Blue
# 23            Unknown         Single  Less than $40K          Blue
# ...               ...            ...             ...           ...
# 10090         Unknown        Married     $40K - $60K          Blue
# 10094         Unknown         Single     $60K - $80K          Blue
# 10095         Unknown        Married    $80K - $120K          Blue
# 10118         Unknown        Unknown    $80K - $120K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 6                  46  ...       34516.0                 2264
# 11                 54  ...        9095.0                 1587
# 15                 37  ...        4234.0                  972
# 17                 34  ...       13535.0                 1291
# 23                 36  ...        2492.0                 1560
# ...               ...  ...           ...                  ...
# 10090              22  ...       12958.0                 2273
# 10094              48  ...        7288.0                    0
# 10095              33  ...       34516.0                 1099
# 10118              36  ...        9959.0                  952
# 10123              25  ...        4277.0                 2186
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 6              32252.0                 1.975             1330              31
# 11              7508.0                 1.433             1314              26
# 15              3262.0                 1.707             1348              27
# 17             12244.0                 0.653             1028              21
# 23               932.0                 0.573             1126              23
# ...                ...                   ...              ...             ...
# 10090          10685.0                 0.608            15681              96
# 10094           7288.0                 0.640            14873             120
# 10095          33417.0                 0.816            15490             110
# 10118           9007.0                 0.825            10310              63
# 10123           2091.0                 0.804             8764              69
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 6                    0.722                  0.066
# 11                   1.364                  0.174
# 15                   1.700                  0.230
# 17                   1.625                  0.095
# 23                   0.353                  0.626
# ...                    ...                    ...
# 10090                0.627                  0.175
# 10094                0.714                  0.000
# 10095                0.618                  0.032
# 10118                1.100                  0.096
# 10123                0.683                  0.511
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 6                                               0.000123
# 11                                              0.000198
# 15                                              0.000063
# 17                                              0.000150
# 23                                              0.000207
# ...                                                  ...
# 10090                                           0.000345
# 10094                                           0.000057
# 10095                                           0.000106
# 10118                                           0.998130
# 10123                                           0.995270
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 6                                               0.999880
# 11                                              0.999800
# 15                                              0.999940
# 17                                              0.999850
# 23                                              0.999790
# ...                                                  ...
# 10090                                           0.999650
# 10094                                           0.999940
# 10095                                           0.999890
# 10118                                           0.001874
# 10123                                           0.004729
#
# [1519 rows x 23 columns]

# %% [markdown]
# Hay 1519 rows con Education Level = unknown, lo que quiere decir que nos conviene más mantenerlos o perderemos un gran porcentaje de registros.
#
# Vamos a revisar ahora Income Category

# %%
df[df.Income_Category=="Unknown"]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 19     709327383  Existing Customer            45      F                2
# 28     718813833  Existing Customer            44      F                3
# 39     708300483  Attrited Customer            66      F                0
# 44     720572508  Existing Customer            38      F                4
# 58     711427458  Existing Customer            44      F                5
# ...          ...                ...           ...    ...              ...
# 10021  711149133  Attrited Customer            30      F                1
# 10040  714677583  Attrited Customer            50      F                3
# 10083  718170033  Existing Customer            42      F                4
# 10092  713437008  Attrited Customer            40      F                3
# 10119  716893683  Attrited Customer            55      F                3
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 19           Graduate        Married         Unknown          Blue
# 28         Uneducated         Single         Unknown          Blue
# 39          Doctorate        Married         Unknown          Blue
# 44           Graduate         Single         Unknown          Blue
# 58           Graduate        Married         Unknown          Blue
# ...               ...            ...             ...           ...
# 10021        Graduate        Married         Unknown          Blue
# 10040       Doctorate         Single         Unknown          Blue
# 10083      Uneducated        Married         Unknown          Blue
# 10092        Graduate        Married         Unknown          Blue
# 10119      Uneducated         Single         Unknown          Blue
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 19                 37  ...       14470.0                 1157
# 28                 34  ...       10100.0                    0
# 39                 56  ...        7882.0                  605
# 44                 28  ...        9830.0                 2055
# 58                 35  ...        6273.0                  978
# ...               ...  ...           ...                  ...
# 10021              18  ...        4377.0                 2517
# 10040              36  ...        5173.0                    0
# 10083              23  ...        8348.0                    0
# 10092              25  ...        6888.0                 1878
# 10119              47  ...       14657.0                 2517
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 19             13313.0                 0.966             1207              21
# 28             10100.0                 0.525             1052              18
# 39              7277.0                 1.052              704              16
# 44              7775.0                 0.977             1042              23
# 58              5295.0                 2.275             1359              25
# ...                ...                   ...              ...             ...
# 10021           1860.0                 0.941             8759              74
# 10040           5173.0                 0.912             8757              68
# 10083           8348.0                 0.695            15905             111
# 10092           5010.0                 1.059             9038              64
# 10119          12140.0                 0.166             6009              53
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 19                   0.909                  0.080
# 28                   1.571                  0.000
# 39                   0.143                  0.077
# 44                   0.917                  0.209
# 58                   1.083                  0.156
# ...                    ...                    ...
# 10021                0.609                  0.575
# 10040                0.789                  0.000
# 10083                0.708                  0.000
# 10092                0.829                  0.273
# 10119                0.514                  0.172
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 19                                              0.000055
# 28                                              0.000121
# 39                                              0.997800
# 44                                              0.000317
# 58                                              0.000057
# ...                                                  ...
# 10021                                           0.993300
# 10040                                           0.997800
# 10083                                           0.000059
# 10092                                           0.994990
# 10119                                           0.996910
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 19                                              0.999940
# 28                                              0.999880
# 39                                              0.002197
# 44                                              0.999680
# 58                                              0.999940
# ...                                                  ...
# 10021                                           0.006700
# 10040                                           0.002196
# 10083                                           0.999940
# 10092                                           0.005010
# 10119                                           0.003088
#
# [1112 rows x 23 columns]

# %% [markdown]
# También son más de 1000 registros, por lo que será mejor conservarla.
#
# Ahora veamos Martial Status

# %%
df[df.Marital_Status=="Unknown"]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3      769911858  Existing Customer            40      F                4
# 7      818906208  Existing Customer            32      M                0
# 10     708790833  Existing Customer            42      M                5
# 13     816082233  Existing Customer            35      M                3
# 15     714885258  Existing Customer            44      M                4
# ...          ...                ...           ...    ...              ...
# 10070  747551658  Existing Customer            47      M                3
# 10100  719848008  Existing Customer            39      M                2
# 10101  718372458  Existing Customer            42      M                2
# 10118  713755458  Attrited Customer            50      M                1
# 10125  717406983  Attrited Customer            30      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 3         High School        Unknown  Less than $40K          Blue
# 7         High School        Unknown     $60K - $80K        Silver
# 10         Uneducated        Unknown         $120K +          Blue
# 13           Graduate        Unknown     $60K - $80K          Blue
# 15            Unknown        Unknown    $80K - $120K          Blue
# ...               ...            ...             ...           ...
# 10070     High School        Unknown    $80K - $120K        Silver
# 10100        Graduate        Unknown     $60K - $80K        Silver
# 10101        Graduate        Unknown     $40K - $60K          Blue
# 10118         Unknown        Unknown    $80K - $120K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 3                  34  ...        3313.0                 2517
# 7                  27  ...       29081.0                 1396
# 10                 31  ...        6748.0                 1467
# 13                 30  ...        8547.0                 1666
# 15                 37  ...        4234.0                  972
# ...               ...  ...           ...                  ...
# 10070              40  ...       34516.0                 1371
# 10100              36  ...       29808.0                    0
# 10101              30  ...        3735.0                 1723
# 10118              36  ...        9959.0                  952
# 10125              36  ...        5281.0                    0
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 3                796.0                 1.405             1171              20
# 7              27685.0                 2.204             1538              36
# 10              5281.0                 0.831             1201              42
# 13              6881.0                 1.163             1311              33
# 15              3262.0                 1.707             1348              27
# ...                ...                   ...              ...             ...
# 10070          33145.0                 0.691            15930             123
# 10100          29808.0                 0.669            16098             128
# 10101           2012.0                 0.595            14501              92
# 10118           9007.0                 0.825            10310              63
# 10125           5281.0                 0.535             8395              62
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 3                    2.333                  0.760
# 7                    0.714                  0.048
# 10                   0.680                  0.217
# 13                   2.000                  0.195
# 15                   1.700                  0.230
# ...                    ...                    ...
# 10070                0.836                  0.040
# 10100                0.684                  0.000
# 10101                0.840                  0.461
# 10118                1.100                  0.096
# 10125                0.722                  0.000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 3                                               0.000134
# 7                                               0.000086
# 10                                              0.000191
# 13                                              0.000096
# 15                                              0.000063
# ...                                                  ...
# 10070                                           0.000164
# 10100                                           0.000103
# 10101                                           0.000565
# 10118                                           0.998130
# 10125                                           0.996710
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 3                                               0.999870
# 7                                               0.999910
# 10                                              0.999810
# 13                                              0.999900
# 15                                              0.999940
# ...                                                  ...
# 10070                                           0.999840
# 10100                                           0.999900
# 10101                                           0.999440
# 10118                                           0.001874
# 10125                                           0.003294
#
# [749 rows x 23 columns]

# %% [markdown]
# Tenemos 749 Rows, los suficientes como para decidir no borrarlos

# %% [markdown]
# #### Transformación de datos categóricos a numéricos

# %% [markdown]
# Para Gender vamos a usar One Hot Encoding y remover la columna original, terminaremos con 2 columnas Gender_F y Gender_M

# %%
df_gender = pd.get_dummies(df['Gender'], prefix="Gender", dtype=int)
df = pd.concat([df, df_gender], axis=1).reindex(df.index)
df.drop('Gender', axis=1, inplace=True)
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0      768805383  Existing Customer            45                3
# 1      818770008  Existing Customer            49                5
# 2      713982108  Existing Customer            51                3
# 3      769911858  Existing Customer            40                4
# 4      709106358  Existing Customer            40                3
# ...          ...                ...           ...              ...
# 10122  772366833  Existing Customer            50                2
# 10123  710638233  Attrited Customer            41                2
# 10124  716506083  Attrited Customer            44                1
# 10125  717406983  Attrited Customer            30                2
# 10126  714337233  Attrited Customer            43                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  ...  Avg_Open_To_Buy  \
# 0                  39                         5  ...          11914.0
# 1                  44                         6  ...           7392.0
# 2                  36                         4  ...           3418.0
# 3                  34                         3  ...            796.0
# 4                  21                         5  ...           4716.0
# ...               ...                       ...  ...              ...
# 10122              40                         3  ...           2152.0
# 10123              25                         4  ...           2091.0
# 10124              36                         5  ...           5409.0
# 10125              36                         4  ...           5281.0
# 10126              25                         6  ...           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Gender_F  Gender_M
# 0             0         1
# 1             1         0
# 2             0         1
# 3             1         0
# 4             0         1
# ...         ...       ...
# 10122         0         1
# 10123         0         1
# 10124         1         0
# 10125         0         1
# 10126         1         0
#
# [10127 rows x 24 columns]

# %% [markdown]
# Realmente no necesitamos las 2 columnas Gender_F y Gender_M pues se asume que Gender_F = 0 en realidad es igual a Gender_M = 1, vamos a remover la columna Gender_M

# %%
df.drop('Gender_M', axis=1, inplace=True)
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age  Dependent_count  \
# 0      768805383  Existing Customer            45                3
# 1      818770008  Existing Customer            49                5
# 2      713982108  Existing Customer            51                3
# 3      769911858  Existing Customer            40                4
# 4      709106358  Existing Customer            40                3
# ...          ...                ...           ...              ...
# 10122  772366833  Existing Customer            50                2
# 10123  710638233  Attrited Customer            41                2
# 10124  716506083  Attrited Customer            44                1
# 10125  717406983  Attrited Customer            30                2
# 10126  714337233  Attrited Customer            43                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  ...  Total_Revolving_Bal  \
# 0                  39                         5  ...                  777
# 1                  44                         6  ...                  864
# 2                  36                         4  ...                    0
# 3                  34                         3  ...                 2517
# 4                  21                         5  ...                    0
# ...               ...                       ...  ...                  ...
# 10122              40                         3  ...                 1851
# 10123              25                         4  ...                 2186
# 10124              36                         5  ...                    0
# 10125              36                         4  ...                    0
# 10126              25                         6  ...                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Gender_F
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
# ...         ...
# 10122         0
# 10123         0
# 10124         1
# 10125         0
# 10126         1
#
# [10127 rows x 23 columns]

# %% [markdown]
# Para Education Level vamos a tomar los siguientes valores
#
# 'Unknown' = 0
# 'Uneducated' = 1
# 'High School' = 2
# 'College' = 3
# 'Graduate' = 4
# 'Post-Graduate' = 5
# 'Doctorate' = 6

# %%
df['Education_Level'] = df['Education_Level'].replace({'Unknown' : 0, 'Uneducated' : 1, 'High School' : 2, 'College' : 3, 'Graduate': 4, 'Post-Graduate' : 5, 'Doctorate' : 6})
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Education_Level  \
# count  1.012700e+04  10127.000000     10127.000000     10127.000000
# mean   7.391776e+08     46.325960         2.346203         2.601955
# std    3.690378e+07      8.016814         1.298908         1.700417
# min    7.080821e+08     26.000000         0.000000         0.000000
# 25%    7.130368e+08     41.000000         1.000000         1.000000
# 50%    7.179264e+08     46.000000         2.000000         3.000000
# 75%    7.731435e+08     52.000000         3.000000         4.000000
# max    8.283431e+08     73.000000         5.000000         6.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        35.928409                  3.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min         13.000000                  1.000000                0.000000
# 25%         31.000000                  3.000000                2.000000
# 50%         36.000000                  4.000000                2.000000
# 75%         40.000000                  5.000000                3.000000
# max         56.000000                  6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990
#
#            Gender_F
# count  10127.000000
# mean       0.529081
# std        0.499178
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# Para Income category, vamos a utilizar los siguientes valores
# 'Unknown' = 0
#
# 'Less than $40K' = 1
#
# '$40K - $60K' = 2
#
# '$60K - $80K' = 3
#
# '$80K - $120K' = 4
#
# '$120K +' = 5

# %%
df['Income_Category'] = df['Income_Category'].replace({'Unknown' : 0, 'Less than $40K' : 1, '$40K - $60K' : 2, '$60K - $80K' : 3, '$80K - $120K': 4, '$120K +' : 5})
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Education_Level  \
# count  1.012700e+04  10127.000000     10127.000000     10127.000000
# mean   7.391776e+08     46.325960         2.346203         2.601955
# std    3.690378e+07      8.016814         1.298908         1.700417
# min    7.080821e+08     26.000000         0.000000         0.000000
# 25%    7.130368e+08     41.000000         1.000000         1.000000
# 50%    7.179264e+08     46.000000         2.000000         3.000000
# 75%    7.731435e+08     52.000000         3.000000         4.000000
# max    8.283431e+08     73.000000         5.000000         6.000000
#
#        Income_Category  Months_on_book  Total_Relationship_Count  \
# count     10127.000000    10127.000000              10127.000000
# mean          2.085711       35.928409                  3.812580
# std           1.474639        7.986416                  1.554408
# min           0.000000       13.000000                  1.000000
# 25%           1.000000       31.000000                  3.000000
# 50%           2.000000       36.000000                  4.000000
# 75%           3.000000       40.000000                  5.000000
# max           5.000000       56.000000                  6.000000
#
#        Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# count            10127.000000           10127.000000  10127.000000
# mean                 2.341167               2.455317   8631.953698
# std                  1.010622               1.106225   9088.776650
# min                  0.000000               0.000000   1438.300000
# 25%                  2.000000               2.000000   2555.000000
# 50%                  2.000000               2.000000   4549.000000
# 75%                  3.000000               3.000000  11067.500000
# max                  6.000000               6.000000  34516.000000
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# count         10127.000000     10127.000000          10127.000000
# mean           1162.814061      7469.139637              0.759941
# std             814.987335      9090.685324              0.219207
# min               0.000000         3.000000              0.000000
# 25%             359.000000      1324.500000              0.631000
# 50%            1276.000000      3474.000000              0.736000
# 75%            1784.000000      9859.000000              0.859000
# max            2517.000000     34516.000000              3.397000
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# count     10127.000000    10127.000000         10127.000000
# mean       4404.086304       64.858695             0.712222
# std        3397.129254       23.472570             0.238086
# min         510.000000       10.000000             0.000000
# 25%        2155.500000       45.000000             0.582000
# 50%        3899.000000       67.000000             0.702000
# 75%        4741.000000       81.000000             0.818000
# max       18484.000000      139.000000             3.714000
#
#        Avg_Utilization_Ratio  \
# count           10127.000000
# mean                0.274894
# std                 0.275691
# min                 0.000000
# 25%                 0.023000
# 50%                 0.176000
# 75%                 0.503000
# max                 0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990
#
#            Gender_F
# count  10127.000000
# mean       0.529081
# std        0.499178
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# Vamos a convertir Marital Status a Ordinal también, estuvimos debatiendo si debería ser OneHotEncoding o no, pero al parecer podemos establecer el siguiente orden
# 'Unknown' = 0
# 'Single' = 1
# 'Married' = 2
# 'Divorced' = 3

# %%
df['Marital_Status'] = df['Marital_Status'].replace({'Unknown' : 0, 'Single' : 1, 'Married' : 2, 'Divorced' : 3})
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Education_Level  \
# count  1.012700e+04  10127.000000     10127.000000     10127.000000
# mean   7.391776e+08     46.325960         2.346203         2.601955
# std    3.690378e+07      8.016814         1.298908         1.700417
# min    7.080821e+08     26.000000         0.000000         0.000000
# 25%    7.130368e+08     41.000000         1.000000         1.000000
# 50%    7.179264e+08     46.000000         2.000000         3.000000
# 75%    7.731435e+08     52.000000         3.000000         4.000000
# max    8.283431e+08     73.000000         5.000000         6.000000
#
#        Marital_Status  Income_Category  Months_on_book  \
# count    10127.000000     10127.000000    10127.000000
# mean         1.536585         2.085711       35.928409
# std          0.737808         1.474639        7.986416
# min          0.000000         0.000000       13.000000
# 25%          1.000000         1.000000       31.000000
# 50%          2.000000         2.000000       36.000000
# 75%          2.000000         3.000000       40.000000
# max          3.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# count           10127.000000  ...         10127.000000     10127.000000
# mean                2.455317  ...          1162.814061      7469.139637
# std                 1.106225  ...           814.987335      9090.685324
# min                 0.000000  ...             0.000000         3.000000
# 25%                 2.000000  ...           359.000000      1324.500000
# 50%                 2.000000  ...          1276.000000      3474.000000
# 75%                 3.000000  ...          1784.000000      9859.000000
# max                 6.000000  ...          2517.000000     34516.000000
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count          10127.000000     10127.000000    10127.000000
# mean               0.759941      4404.086304       64.858695
# std                0.219207      3397.129254       23.472570
# min                0.000000       510.000000       10.000000
# 25%                0.631000      2155.500000       45.000000
# 50%                0.736000      3899.000000       67.000000
# 75%                0.859000      4741.000000       81.000000
# max                3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990
#
#            Gender_F
# count  10127.000000
# mean       0.529081
# std        0.499178
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# Card Category es otra que también podemos convertir a Ordinal de la siguiente manera
# 'Blue' = 1
# 'Silver' = 2
# 'Gold' = 3
# 'Platinum' = 4

# %%
df['Card_Category'] = df['Card_Category'].replace({'Blue' : 1, 'Silver' : 2, 'Gold' : 3, 'Platinum' : 4})
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Education_Level  \
# count  1.012700e+04  10127.000000     10127.000000     10127.000000
# mean   7.391776e+08     46.325960         2.346203         2.601955
# std    3.690378e+07      8.016814         1.298908         1.700417
# min    7.080821e+08     26.000000         0.000000         0.000000
# 25%    7.130368e+08     41.000000         1.000000         1.000000
# 50%    7.179264e+08     46.000000         2.000000         3.000000
# 75%    7.731435e+08     52.000000         3.000000         4.000000
# max    8.283431e+08     73.000000         5.000000         6.000000
#
#        Marital_Status  Income_Category  Card_Category  Months_on_book  \
# count    10127.000000     10127.000000   10127.000000    10127.000000
# mean         1.536585         2.085711       1.083638       35.928409
# std          0.737808         1.474639       0.333784        7.986416
# min          0.000000         0.000000       1.000000       13.000000
# 25%          1.000000         1.000000       1.000000       31.000000
# 50%          2.000000         2.000000       1.000000       36.000000
# 75%          2.000000         3.000000       1.000000       40.000000
# max          3.000000         5.000000       4.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  ...  \
# count              10127.000000            10127.000000  ...
# mean                   3.812580                2.341167  ...
# std                    1.554408                1.010622  ...
# min                    1.000000                0.000000  ...
# 25%                    3.000000                2.000000  ...
# 50%                    4.000000                2.000000  ...
# 75%                    5.000000                3.000000  ...
# max                    6.000000                6.000000  ...
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# count         10127.000000     10127.000000          10127.000000
# mean           1162.814061      7469.139637              0.759941
# std             814.987335      9090.685324              0.219207
# min               0.000000         3.000000              0.000000
# 25%             359.000000      1324.500000              0.631000
# 50%            1276.000000      3474.000000              0.736000
# 75%            1784.000000      9859.000000              0.859000
# max            2517.000000     34516.000000              3.397000
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# count     10127.000000    10127.000000         10127.000000
# mean       4404.086304       64.858695             0.712222
# std        3397.129254       23.472570             0.238086
# min         510.000000       10.000000             0.000000
# 25%        2155.500000       45.000000             0.582000
# 50%        3899.000000       67.000000             0.702000
# 75%        4741.000000       81.000000             0.818000
# max       18484.000000      139.000000             3.714000
#
#        Avg_Utilization_Ratio  \
# count           10127.000000
# mean                0.274894
# std                 0.275691
# min                 0.000000
# 25%                 0.023000
# 50%                 0.176000
# 75%                 0.503000
# max                 0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990
#
#            Gender_F
# count  10127.000000
# mean       0.529081
# std        0.499178
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Análisis Univariante

# %%
df.select_dtypes(include=np.number)
# Out:
#        CLIENTNUM  Customer_Age  Dependent_count  Education_Level  \
# 0      768805383            45                3                2
# 1      818770008            49                5                4
# 2      713982108            51                3                4
# 3      769911858            40                4                2
# 4      709106358            40                3                1
# ...          ...           ...              ...              ...
# 10122  772366833            50                2                4
# 10123  710638233            41                2                0
# 10124  716506083            44                1                2
# 10125  717406983            30                2                4
# 10126  714337233            43                2                4
#
#        Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0                   2                3              1              39
# 1                   1                1              1              44
# 2                   2                4              1              36
# 3                   0                1              1              34
# 4                   2                3              1              21
# ...               ...              ...            ...             ...
# 10122               1                2              1              40
# 10123               3                2              1              25
# 10124               2                1              1              36
# 10125               0                2              1              36
# 10126               2                1              2              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  ...  \
# 0                             5                       1  ...
# 1                             6                       1  ...
# 2                             4                       1  ...
# 3                             3                       4  ...
# 4                             5                       1  ...
# ...                         ...                     ...  ...
# 10122                         3                       2  ...
# 10123                         4                       2  ...
# 10124                         5                       3  ...
# 10125                         4                       3  ...
# 10126                         6                       2  ...
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                      777          11914.0                 1.335
# 1                      864           7392.0                 1.541
# 2                        0           3418.0                 2.594
# 3                     2517            796.0                 1.405
# 4                        0           4716.0                 2.175
# ...                    ...              ...                   ...
# 10122                 1851           2152.0                 0.703
# 10123                 2186           2091.0                 0.804
# 10124                    0           5409.0                 0.819
# 10125                    0           5281.0                 0.535
# 10126                 1961           8427.0                 0.703
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1144              42                1.625
# 1                 1291              33                3.714
# 2                 1887              20                2.333
# 3                 1171              20                2.333
# 4                  816              28                2.500
# ...                ...             ...                  ...
# 10122            15476             117                0.857
# 10123             8764              69                0.683
# 10124            10291              60                0.818
# 10125             8395              62                0.722
# 10126            10294              61                0.649
#
#        Avg_Utilization_Ratio  \
# 0                      0.061
# 1                      0.105
# 2                      0.000
# 3                      0.760
# 4                      0.000
# ...                      ...
# 10122                  0.462
# 10123                  0.511
# 10124                  0.000
# 10125                  0.000
# 10126                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Gender_F
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
# ...         ...
# 10122         0
# 10123         0
# 10124         1
# 10125         0
# 10126         1
#
# [10127 rows x 22 columns]

# %% [markdown]
# #### Boxplot

# %%
#Graficar Boxplot de Variables Importantes
df_campos_num = df[["Customer_Age","Total_Trans_Ct","Dependent_count","Months_on_book","Total_Relationship_Count","Months_Inactive_12_mon","Contacts_Count_12_mon","Credit_Limit","Total_Revolving_Bal","Avg_Open_To_Buy","Avg_Utilization_Ratio", "Education_Level", "Marital_Status", "Income_Category", "Card_Category", "Gender_F"]] #>>>>>>>>>>>>>>>>>>>>HAY QUE AGREGAR MAS    // df.select_dtypes(include=np.number)  #

numcol = df_campos_num.columns.size

plt.subplots(nrows=4, ncols=5, figsize=(20,15))
for i in range(numcol):
  promedio = df_campos_num[df_campos_num.columns[i]].mean()
  plt.subplot(4,5,1+i)
  plt.boxplot(df_campos_num[df_campos_num.columns[i]]) #plt.hist(df_campos_num[df_campos_num.columns[i]], alpha = 0.5, color = 'b')
  plt.title(df_campos_num.columns[i])
  #plt.axvline(promedio, color='k', linestyle='dashed', linewidth=1)
  #min_ylim, max_ylim = plt.ylim()
  #plt.text(promedio*1.1, max_ylim*0.9, 'Media: {:.2f}'.format(promedio))



plt.show()

# %% [markdown]
# Después de observar los boxplots podemos observar lo siguiente:
# 1. Dimensiones con Outliers: Edad, Total de transacciones, Meses como cliente, Meses inactivo, Conteo de contactos, Límite de crédito
# 2. Tipo de Tarjeta de crédito tiene tantos del primer tipo y tan poco de los niveles elevados que sólo la tarjeta Blue no es considerada Outlier
# 3. En cuanto al Genero, están distribuidos uniformemente entre Masculino y Femenino.
#
# Los puntos 1 y 2 implica que en las siguientes fases del proyecto será necesario hacer una limpieza más a fondo de los datos para remover los outliers

# %% [markdown]
# #### Histogramas

# %%
plt.subplots(nrows=4, ncols=5, figsize=(25,20))
for i in range(numcol):
  plt.subplot(4,5,1+i)
  plt.hist(df_campos_num[df_campos_num.columns[i]], bins=20, color='skyblue', edgecolor='black')
  plt.xlabel("Values")
  plt.ylabel("Frequency")
  plt.title(df_campos_num.columns[i])
  #plt.axvline(promedio, color='k', linestyle='dashed', linewidth=1)
  #min_ylim, max_ylim = plt.ylim()
  #plt.text(promedio*1.1, max_ylim*0.9, 'Media: {:.2f}'.format(promedio))



plt.show()

# %% [markdown]
# Después de observar los histogramas, podemos observar lo siguiente
# 1. La edad de los clientes, el conteo de transacciones, número de depndientes económicos y el número de meses como cliente siguen una distribución normal.
# 2. El Género está prácticamente dividido por igual entre Masculino y Femenino

# %% [markdown]
# ### Análisis bi/multivariante

# %% [markdown]
# #### Matriz de Correlación

# %%
df_corr = df.copy()
df_corr['Attrition_Flag'] = df_corr['Attrition_Flag'].replace({'Attrited Customer' : 0, 'Existing Customer' : 1})
df_campos_num_corr = df_corr[["Attrition_Flag", "Customer_Age","Total_Trans_Ct","Dependent_count","Months_on_book","Total_Relationship_Count","Months_Inactive_12_mon","Contacts_Count_12_mon","Credit_Limit","Total_Revolving_Bal","Avg_Open_To_Buy","Avg_Utilization_Ratio", "Education_Level", "Marital_Status", "Income_Category", "Card_Category", "Gender_F"]]

# %%
df_campos_num_corr.corr()
dataplot = sns.heatmap(df_campos_num_corr.corr(),xticklabels='auto')
plt.show()

# %% [markdown]
# De la matriz de correlación podemos observar que no hay una correlación muy directa entre nuestra variable de salida Attrition_Flag y el resto de las variables numéricas. Haremos un análisis con PCA para obtener más conclusiones.

# %% [markdown]
# #### PCA

# %%
#Normalizar Datos
scaler = MinMaxScaler()
df_campos_num_norm = pd.DataFrame(scaler.fit_transform(df_campos_num))
df_campos_num_norm.describe()
# Out:
#                  0             1             2             3             4   \
# count  10127.000000  10127.000000  10127.000000  10127.000000  10127.000000
# mean       0.432467      0.425261      0.469241      0.533219      0.562516
# std        0.170571      0.181958      0.259782      0.185731      0.310882
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.319149      0.271318      0.200000      0.418605      0.400000
# 50%        0.425532      0.441860      0.400000      0.534884      0.600000
# 75%        0.553191      0.550388      0.600000      0.627907      0.800000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  10127.000000  10127.000000  10127.000000  10127.000000  10127.000000
# mean       0.390195      0.409220      0.217477      0.461984      0.216328
# std        0.168437      0.184371      0.274771      0.323793      0.263399
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333333      0.333333      0.033760      0.142630      0.038290
# 50%        0.333333      0.333333      0.094042      0.506953      0.100571
# 75%        0.500000      0.500000      0.291109      0.708780      0.285574
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  10            11            12            13            14  \
# count  10127.000000  10127.000000  10127.000000  10127.000000  10127.000000
# mean       0.275169      0.433659      0.512195      0.417142      0.027879
# std        0.275967      0.283403      0.245936      0.294928      0.111261
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.023023      0.166667      0.333333      0.200000      0.000000
# 50%        0.176176      0.500000      0.666667      0.400000      0.000000
# 75%        0.503504      0.666667      0.666667      0.600000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  15
# count  10127.000000
# mean       0.529081
# std        0.499178
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
pcs = PCA()

pcs.fit(df_campos_num_norm.dropna(axis=0))

pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                             'Proportion of variance': pcs.explained_variance_ratio_,
                             'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)
                             })
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df
# Out:
#                              PC1       PC2       PC3       PC4       PC5  \
# Standard deviation      0.605418  0.392429  0.332707  0.304953  0.283507
# Proportion of variance  0.321966  0.135276  0.097235  0.081689  0.070603
# Cumulative proportion   0.321966  0.457241  0.554476  0.636165  0.706768
#
#                              PC6       PC7       PC8       PC9      PC10  \
# Standard deviation      0.266235  0.246204  0.231606  0.189880  0.167138
# Proportion of variance  0.062263  0.053246  0.047119  0.031671  0.024538
# Cumulative proportion   0.769031  0.822277  0.869397  0.901067  0.925606
#
#                             PC11      PC12      PC13      PC14      PC15  \
# Standard deviation      0.163674  0.159001  0.132760  0.091550  0.081328
# Proportion of variance  0.023532  0.022207  0.015482  0.007362  0.005810
# Cumulative proportion   0.949138  0.971345  0.986828  0.994190  1.000000
#
#                                 PC16
# Standard deviation      6.961843e-17
# Proportion of variance  4.257429e-33
# Cumulative proportion   1.000000e+00

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(),
                                columns = pcsSummary_df.columns,
                                index = df_campos_num.columns
                                )
pcsComponents_df.iloc[:,:5]

pcsComponents_dfX = pd.DataFrame(pcs.components_.transpose(),
                                columns = pcsSummary_df.columns,
                                index = df_campos_num.columns
                                )

grafica = pcsComponents_dfX.iloc[:,:8]

grafica.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c8a41_row0_col0, #T_c8a41_row4_col5, #T_c8a41_row5_col0, #T_c8a41_row11_col0 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_c8a41_row0_col1, #T_c8a41_row3_col1, #T_c8a41_row10_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_c8a41_row0_col2 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_c8a41_row0_col3, #T_c8a41_row3_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c8a41_row0_col4, #T_c8a41_row5_col4, #T_c8a41_row7_col4, #T_c8a41_row9_col4, #T_c8a41_row10_col4, #T_c8a41_row14_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c8a41_row0_col5 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_c8a41_row0_col6 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_c8a41_row0_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c8a41_row1_col0 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_c8a41_row1_col1, #T_c8a41_row14_col5 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_c8a41_row1_col2, #T_c8a41_row15_col5 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_c8a41_row1_col3, #T_c8a41_row2_col5, #T_c8a41_row3_col7, #T_c8a41_row4_col2, #T_c8a41_row4_col4, #T_c8a41_row8_col1, #T_c8a41_row12_col6, #T_c8a41_row15_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c8a41_row1_col4, #T_c8a41_row6_col4, #T_c8a41_row13_col4, #T_c8a41_row15_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c8a41_row1_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_c8a41_row1_col6, #T_c8a41_row3_col5, #T_c8a41_row4_col3, #T_c8a41_row8_col2, #T_c8a41_row11_col4, #T_c8a41_row12_col7, #T_c8a41_row13_col0, #T_c8a41_row15_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c8a41_row1_col7, #T_c8a41_row15_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_c8a41_row2_col0, #T_c8a41_row14_col2 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_c8a41_row2_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_c8a41_row2_col2, #T_c8a41_row6_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_c8a41_row2_col3, #T_c8a41_row10_col1, #T_c8a41_row11_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c8a41_row2_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c8a41_row2_col6, #T_c8a41_row14_col7 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_c8a41_row2_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_c8a41_row3_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_c8a41_row3_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_c8a41_row3_col4, #T_c8a41_row8_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c8a41_row3_col6 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_c8a41_row4_col0 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_c8a41_row4_col1 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_c8a41_row4_col6 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_c8a41_row4_col7, #T_c8a41_row9_col5 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_c8a41_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_c8a41_row5_col2, #T_c8a41_row7_col3 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_c8a41_row5_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c8a41_row5_col5, #T_c8a41_row8_col5 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_c8a41_row5_col6, #T_c8a41_row7_col1, #T_c8a41_row9_col2 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_c8a41_row5_col7, #T_c8a41_row14_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_c8a41_row6_col1, #T_c8a41_row12_col5 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_c8a41_row6_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_c8a41_row6_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_c8a41_row6_col5 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_c8a41_row6_col6 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_c8a41_row6_col7 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_c8a41_row7_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_c8a41_row7_col2 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_c8a41_row7_col5 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_c8a41_row7_col6, #T_c8a41_row9_col6 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_c8a41_row7_col7 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_c8a41_row8_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_c8a41_row8_col3 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_c8a41_row8_col6 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_c8a41_row8_col7 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_c8a41_row9_col0 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_c8a41_row9_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_c8a41_row9_col3 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_c8a41_row9_col7 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_c8a41_row10_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_c8a41_row10_col2 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_c8a41_row10_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_c8a41_row10_col6 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_c8a41_row10_col7 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_c8a41_row11_col1 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_c8a41_row11_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_c8a41_row11_col5 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_c8a41_row11_col6 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_c8a41_row11_col7 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_c8a41_row12_col0 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_c8a41_row12_col1 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_c8a41_row12_col2 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_c8a41_row12_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c8a41_row12_col4 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_c8a41_row13_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_c8a41_row13_col2 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_c8a41_row13_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c8a41_row13_col5 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_c8a41_row13_col6 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_c8a41_row13_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_c8a41_row14_col1 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_c8a41_row14_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c8a41_row14_col6 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_c8a41_row15_col2 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_c8a41_row15_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_c8a41_row15_col7 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8a41" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8a41_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_c8a41_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_c8a41_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_c8a41_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_c8a41_level0_col4" class="col_heading level0 col4" >PC5</th>
#       <th id="T_c8a41_level0_col5" class="col_heading level0 col5" >PC6</th>
#       <th id="T_c8a41_level0_col6" class="col_heading level0 col6" >PC7</th>
#       <th id="T_c8a41_level0_col7" class="col_heading level0 col7" >PC8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8a41_level0_row0" class="row_heading level0 row0" >Customer_Age</th>
#       <td id="T_c8a41_row0_col0" class="data row0 col0" >-0.002310</td>
#       <td id="T_c8a41_row0_col1" class="data row0 col1" >-0.005638</td>
#       <td id="T_c8a41_row0_col2" class="data row0 col2" >-0.000931</td>
#       <td id="T_c8a41_row0_col3" class="data row0 col3" >0.004408</td>
#       <td id="T_c8a41_row0_col4" class="data row0 col4" >0.004196</td>
#       <

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]+100,y[i]+100)

# %% [markdown]
# ### Analisis de la variable objetivo

# %%
#ANALISIS DE VARIABLE OBJETIVO
df_y = df[["Attrition_Flag"]] #variable objetivo

clases = list(["Cliente Actual", "Abandono"])
values = list([
    len(df[df['Attrition_Flag'] == 'Existing Customer']),
    len(df[df['Attrition_Flag'] == 'Attrited Customer'])
    ])

fig = plt.figure(figsize = (10, 5))

plt.bar(clases, values, color ='green', width = 0.4)

addlabels(clases, values)




plt.xlabel("Clase")
plt.ylabel("Registros")
plt.title("Variable Objetivo")
plt.show()

# %% [markdown]
# Podemos observar que nuestra variable de salida no está balanceada, pues tenemos casi 5 veces más instancias de *cliente actual* comparado con *abandono* esto lo tomaremos en cuenta en las siguientes partes del proceso

# %% [markdown]
# ### Conclusiones
#
# #### ¿Hay valores faltantes en el conjunto de los datos? ¿Se pueden identificar patrones de ausencia?
# El dataset original no tenía valores nulos, lo cual facilita la limpieza de datos. Sin embargo, sí tenía datos categóricos que fue necesario convertir a numéricos y decidir cuál sería la mejor manera de hacerlo. Además, dentro de esos datos categóricos se pudo observar con la categoría "unknown" (Desconocido), se analizó los datos para identificar si era mejor exluir esos registros o definir la categoría "unknown" como uno de los valores posible dentro de los datos.
#
# #### ¿Cuáles son las estadísitcas resumidas del conjunto de datos?
# El dataset contiene un total de 10,327 registros, de los cuales 8,600 pertenecen a la clase "Cliente Actual" y 1727 pertencen a la clase "Abandono".
#
# #### ¿Hay valores atípicos en el conjunto de los datos?
# También encontramos que algunas de las variables cuentan con outliers e incluso una de ellas, Tipo de Tarjeta, considera que todas las opciones, menos una, es outlier, lo cual implica que Tipo de Tarjeta pudiera removerse del dataset, pues al remover los outliers todos los registros quedarian con un solo valor y no sería determinante para el modelo.
#
# #### ¿Cuál es la cardinalidad de las variables categóricas?
# Pudimos observar las variables categóricas Tipo de Tarjeta (4 valores), Nivel de Educación (6 valores), Nivel de Ingreso (5 valores) y Estado civil (4 valores)
#
# #### ¿Se identifican tendencias temporales?
# La variable de tiempo incluida en el dataset es el número de meses como cliente, la cual muestra una distribución normal, sin embargo en el análisis de correlación no se identificó una clara correlación con la variable de salida.
#
# #### ¿Hay correlación entre las variables dependientes e independientes?
# Durante el análisis de la matriz de correlación se encontró que no hay una marcada correlación entre la variable de salida y ninguna de las otras variables en particular. De ahí, se optó por hacer un análisis PCA.
#
# Para relaizar en análisis PCA fue necesario hacer una normalización de los datos pues los datos estaban en escalas muy diferentes.
#
# #### ¿Cómo se distribuyen los datos en función de diferentes categorías?
# Dentro de las variables podemos observar algunas con distribución normal como edad del cliente, total de transacciones o número de meses en el registro. También podemos observar algunas variables con distribución logarítmica como límite de crédito o tasa de utilización.
#
# #### ¿Se deberían normalizar las imágenes para visualizarlas mejor?
# Este dataset no incluye imágenes por lo que no es necesario hacer ningún tipo de manipulación al respecto.
#
# #### ¿Hay desequilibrio en las clases de la variable objetivo?
# Por último se analizó la variable de salida, donde se pudo observar que hay 5 veces más registros de la categoría cliente actual comparada contra abandono. Por lo que en las siguientes etapas del proyecto se tendrá que hacer un balanceo de clases.

# %% [markdown]
# ### Referencias
# 1. Brownlee, J. (2020, 17 agosto). *Ordinal and One-Hot Encodings for Categorical Data.* MachineLearningMastery.com. Recuperado el 4 de Mayo de 2024 https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/
# 2. Crêteur, S. (2022, 16 diciembre). *Machine learning: one-hot encoding vs integer encoding*. Medium. Recuperado el 4 de Mayo de 2024 de https://medium.com/geekculture/
# 3. Galarnyk, M. (2023, 26 julio). *Understanding boxplots.* Built In. Recuperado el 4 de Mayo de 2024 https://builtin.com/data-science/boxplot
# 4. GeeksforGeeks. (2023, 6 abril). *How to convert categorical string data into numeric in Python?* GeeksforGeeks. Recuperado el 4 de Mayo de 2024. https://www.geeksforgeeks.org/how-to-convert-categorical-string-data-into-numeric-in-python/
# 5. GeeksforGeeks. (2024, 21 marzo). *How to create a seaborn correlation heatmap in Python?* GeeksforGeeks. Recuperado el 4 de Mayo de 2024. https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
# 6. GeeksforGeeks. (2024a, enero 9). *Plotting Histogram in Python using Matplotlib.* GeeksforGeeks. Recuperado el 5 de Mayo de 2024 https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
# 7. Jafari, R. (2022). *Hands-On Data Preprocessing in Python: Learn How to Effectively Prepare Data for Successful Data Analytics.* Packt.
# 8. Kumar Mukhiya, S., y Ahmed, U. (2020). *Hands-On Exploratory Data Analysis with Python*. Packt Publishing
# machine-learning-one-hot-encoding-vs-integer-encoding-f180eb831cf1
# 9. Pulagam, S. (2021, 14 diciembre). *All you need to know about PCA technique in Machine Learning*. Medium. Recuperado el 3 de Mayo de 2024 de https://towardsdatascience.com/all-you-need-to-know-about-pca-technique-in-machine-learning-443b0c2be9a1
# 10. Saturn Cloud Blog. (2024, 5 enero). *How to Convert Categorical Data to Numerical Data with Pandas* Recuperado el 4 de Mayo de 2024 https://saturncloud.io/blog/how-to-convert-categorical-data-to-numerical-data-with-pandas/
